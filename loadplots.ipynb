# %%
from lib.loaddata.loadplotsfromwiki import get_wiki_all_seasons_plots
from lib.loaddata.loadplotsfromwiki import CARTONS, CARTOON_WIKI

# %%
get_wiki_all_seasons_plots(CARTOON_WIKI[CARTONS['Simpsons']], 26)
# Out:
#         no_overall  no_season no_in_season                              title  \
# 0   NaN          1        0.0            1  Simpsons Roasting on an Open Fire
# 1   NaN          2        0.0            2                    Bart the Genius
# 2   NaN          3        0.0            3                    Homer's Odyssey
# 3   NaN          4        0.0            4      There's No Disgrace Like Home
# 4   NaN          5        0.0            5                   Bart the General
# ..  ...        ...        ...          ...                                ...
# 17  NaN        570       25.0           18                        Peeping Mom
# 18  NaN        571       25.0           19             The Kids Are All Fight
# 19  NaN        572       25.0           20                Let's Go Fly a Coot
# 20  NaN        573       25.0           21                             Bull-E
# 21  NaN        574       25.0           22                    Mathlete's Feat
#
# ...

# %%
get_wiki_all_seasons_plots(CARTOON_WIKI[CARTONS['South Park']], 25)
# Out:
#         no_overall  no_season no_in_season  \
# 0   NaN          1        0.0            1
# 1   NaN          2        0.0            2
# 2   NaN          3        0.0            3
# 3   NaN          4        0.0            4
# 4   NaN          5        0.0            5
# ..  ...        ...        ...          ...
# 1   NaN        313       24.0            2
# 2   NaN        314       24.0            3
# 3   NaN        315       24.0            4
# 4   NaN        316       24.0            5
# 5   NaN        317       24.0            6
#
#                                        title  \
# 0                 Cartman Gets an Anal Probe
# 1                           Weight Gain 4000
# 2                                    Volcano
# 3             Big Gay Al's Big Gay Boat Ride
# 4            An Elephant Makes Love to a Pig
# ..                                       ...
# 1                                The Big Fix
# 2                                City People
# ...

# %%
get_wiki_all_seasons_plots(CARTOON_WIKI[CARTONS['Futurama']], 7)
# Out:
#         no_overall  no_season no_in_season                         title  \
# 0   NaN          1        0.0            1              Space Pilot 3000
# 1   NaN          2        0.0            2         The Series Has Landed
# 2   NaN          3        0.0            3                   I, Roommate
# 3   NaN          4        0.0            4  Love's Labours Lost in Space
# 4   NaN          5        0.0            5          Fear of a Bot Planet
# ..  ...        ...        ...          ...                           ...
# 21  NaN        136        6.0           22       Leela and the Genestalk
# 22  NaN        137        6.0           23                 Game of Tones
# 23  NaN        138        6.0           24  Murder on the Planet Express
# 24  NaN        139        6.0           25      Stench and Stenchibility
# 25  NaN        140        6.0           26                     Meanwhile
#
#                                            plot_small  \
# ...
